# %%
import pandas as pd
import numpy as np
import os

#!pip install --upgrade pip
# !pip install sympy
from sympy import Eq, Symbol, solve
# Out:
# Requirement already satisfied: sympy in ./opt/miniconda3/envs/tf/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: mpmath>=0.19 in ./opt/miniconda3/envs/tf/lib/python3.9/site-packages (from sympy) (1.2.1)

# %%
#########################import data################

bond_Path = '~/downloads/FW__Programming_assignment/bond_portfolio.xlsx'
bond_data = pd.read_excel(bond_Path)
bond_data


yld_Path = '~/downloads/FW__Programming_assignment/yield_curve.csv'
yld_data = pd.read_csv(yld_Path, sep = ";")
yld_data
# Out:
#    Term  Rate
# 0   0.5   0.0
# 1   1.0   0.5
# 2   2.0   0.7
# 3   3.0   0.7
# 4   5.0   0.9
# 5   7.0   1.0
# 6  10.0   2.0
# 7  15.0   2.5
# 8  20.0   3.0
# 9  30.0   3.5

# %%
bond_data
# Out:
#        Name  Price  Coupon Frequency  Maturity   Nominal
# 0    Bond 1    102     2.0    Annual         5    100000
# 1    Bond 2    100     3.0    Annual         7    100000
# 2    Bond 3     84     1.0    Annual        15   1000000
# 3    Bond 4     92     5.0    Annual        17     50000
# 4    Bond 5     97     3.0    Annual         9    500000
# 5    Bond 6     90     1.0    Annual        19    100000
# 6    Bond 7     88     1.5    Annual        12   1000000
# 7    Bond 8     93     5.5    Annual        16    500000
# 8    Bond 9     94     4.0    Annual        10    100000
# 9   Bond 10     92     4.5    Annual        11     50000
# 10  Bond 11     75     5.5    Annual        12    100000
# 11  Bond 12     67     5.0    Annual        25   5000000
# 12  Bond 13     87     4.0    Annual        18    100000
# 13  Bond 14     94     5.0    Annual        19    500000
# 14  Bond 15     93     3.5    Annual         3    500000
# 15  Bond 16    101     2.0    Annual         2    100000
# 16  Bond 17    100     3.5    Annual         3  10000000
# 17  Bond 18     78     3.0    Annual        21   5000000
# 18  Bond 19     81     2.5    Annual        23   5000000
# 19  Bond 20     91     3.0    Annual        24  10000000

# %%
def mktvalue(df):
    price = df['Price']
    coupon = df['Coupon']
    m = df['Maturity']*0.01   ##coupons in percenatge
    
    df['Market value'] = price*(1+coupon)**m
    
    return(df)


df = mktvalue(bond_data)


df["Maturity"] = pd.to_numeric(df["Maturity"], downcast="float")
df['Coupon'] = df['Coupon']*0.01          ###coupon in percentages
df
# Out:
#        Name  Price  Coupon Frequency  Maturity   Nominal  Market value
# 0    Bond 1    102   0.020    Annual       5.0    100000    107.759665
# 1    Bond 2    100   0.030    Annual       7.0    100000    110.190512
# 2    Bond 3     84   0.010    Annual      15.0   1000000     93.203836
# 3    Bond 4     92   0.050    Annual      17.0     50000    124.759475
# 4    Bond 5     97   0.030    Annual       9.0    500000    109.889737
# 5    Bond 6     90   0.010    Annual      19.0    100000    102.668734
# 6    Bond 7     88   0.015    Annual      12.0   1000000     98.228039
# 7    Bond 8     93   0.055    Annual      16.0    500000    125.472654
# 8    Bond 9     94   0.040    Annual      10.0    100000    110.414181
# 9   Bond 10     92   0.045    Annual      11.0     50000    110.975657
# 10  Bond 11     75   0.055    Annual      12.0    100000     93.888168
# 11  Bond 12     67   0.050    Annual      25.0   5000000    104.860667
# 12  Bond 13     87   0.040    Annual      18.0    100000    116.234179
# 13  Bond 14     94   0.050    Annual      19.0    500000    132.122442
# 14  Bond 15     93   0.035    Annual       3.0    500000     97.292491
# 15  Bond 16    101   0.020    Annual       2.0    100000    103.243757
# 16  Bond 17    100   0.035    Annual       3.0  10000000    104.615582
# 17  Bond 18     78   0.030    Annual      21.0   5000000    104.358349
# 18  Bond 19     81   0.025    Annual      23.0   5000000    108.048979
# 19  Bond 20     91   0.030    Annual      24.0  10000000    126.921674

# %%
yld_data['term diff'] = yld_data['Term'].diff()
yld_data['Rate diff'] = yld_data['Rate'].diff()
yld_data['annual diff'] = yld_data['Rate diff']/yld_data['term diff']
yld_data

yld_data["Term"] = pd.to_numeric(yld_data["Term"], downcast="float")
yld_data
# Out:
#    Term  Rate  term diff  Rate diff  annual diff
# 0   0.5   0.0        NaN        NaN          NaN
# 1   1.0   0.5        0.5        0.5     1.000000
# 2   2.0   0.7        1.0        0.2     0.200000
# 3   3.0   0.7        1.0        0.0     0.000000
# 4   5.0   0.9        2.0        0.2     0.100000
# 5   7.0   1.0        2.0        0.1     0.050000
# 6  10.0   2.0        3.0        1.0     0.333333
# 7  15.0   2.5        5.0        0.5     0.100000
# 8  20.0   3.0        5.0        0.5     0.100000
# 9  30.0   3.5       10.0        0.5     0.050000

# %%
###################part1: discounted market price###################

df['discount rate'] = 'other'


for i in range(0,len(df)):
    for j in range(0,len(yld_data)):

        if df.iloc[i,4] == yld_data.iloc[j,0]:
            
            df.iloc[i,7] = yld_data.iloc[j,1]
            
            

        if (df.iloc[i,4]>3) and (df.iloc[i,4]<5):
            df.iloc[i,7] = (df.iloc[i,4]-3)*yld_data.iloc[4,4] + yld_data.iloc[3,1]
        
        if (df.iloc[i,4]>5) and (df.iloc[i,4]<7):
            df.iloc[i,7] = (df.iloc[i,4]-5)*yld_data.iloc[5,4] + yld_data.iloc[4,1]
        if (df.iloc[i,4]>7) and (df.iloc[i,4]<10):
            df.iloc[i,7] = (df.iloc[i,4]-7)*yld_data.iloc[6,4] + yld_data.iloc[5,1]
        if (df.iloc[i,4]>10) and (df.iloc[i,4]<15):
            df.iloc[i,7] = (df.iloc[i,4]-10)*yld_data.iloc[7,4] + yld_data.iloc[6,1]
        if (df.iloc[i,4]>15) and (df.iloc[i,4]<20):
            df.iloc[i,7] = (df.iloc[i,4]-15)*yld_data.iloc[8,4] + yld_data.iloc[7,1]
        if (df.iloc[i,4]>20) and (df.iloc[i,4]<30):
            df.iloc[i,7] = (df.iloc[i,4]-20)*yld_data.iloc[9,4] + yld_data.iloc[8,1]
        
        
        else:
            pass
              
df['discount rate'] = df['discount rate']*0.01  ###rate in 100%? 
df['discounted price'] = df['Market value']/(1+df['discount rate'])
df
# Out:
#        Name  Price  Coupon Frequency  Maturity   Nominal  Market value  \
# 0    Bond 1    102   0.020    Annual       5.0    100000    107.759665
# 1    Bond 2    100   0.030    Annual       7.0    100000    110.190512
# 2    Bond 3     84   0.010    Annual      15.0   1000000     93.203836
# 3    Bond 4     92   0.050    Annual      17.0     50000    124.759475
# 4    Bond 5     97   0.030    Annual       9.0    500000    109.889737
# 5    Bond 6     90   0.010    Annual      19.0    100000    102.668734
# 6    Bond 7     88   0.015    Annual      12.0   1000000     98.228039
# 7    Bond 8     93   0.055    Annual      16.0    500000    125.472654
# 8    Bond 9     94   0.040    Annual      10.0    100000    110.414181
# 9   Bond 10     92   0.045    Annual      11.0     50000    110.975657
# 10  Bond 11     75   0.055    Annual      12.0    100000     93.888168
# 11  Bond 12     67   0.050    Annual      25.0   5000000    104.860667
# 12  Bond 13     87   0.040    Annual      18.0    100000    116.234179
# 13  Bond 14     94   0.050    Annual      19.0    500000    132.122442
# 14  Bond 15     93   0.035    Annual       3.0    500000     97.292491
# 15  Bond 16    101   0.020    Annual       2.0    100000    103.243757
# 16  Bond 17    100   0.035    Annual       3.0  10000000    104.615582
# 17  Bond 18     78   0.030    Annual      21.0   5000000    104.358349
# 18  Bond 19     81   0.025    Annual      23.0   5000000    108.048979
# 19  Bond 20     91   0.030    Annual      24.0  10000000    126.921674
#
#    discount rate discounted price
# 0          0.009       106.798479
# 1           0.01       109.099516
# 2          0.025        90.930571
# 3          0.027       121.479528
# 4       0.016667       108.088266
# 5          0.029        99.775252
# 6          0.022        96.113541
# 7          0.026       122.293035
# 8           0.02       108.249197
# 9          0.021       108.693101
# 10         0.022        91.867092
# 11        0.0325       101.559968
# 12         0.028       113.068268
# 13         0.029       128.398874
# 14         0.007        96.616178
# 15         0.007       102.526074
# 16         0.007       103.888363
# 17        0.0305       101.269626
# 18        0.0315       104.749374
# 19         0.032       122.986118

# %%
######### part 2: get z spread###################


def zspread(p, maturity,coupon):    ##rate for zero coupon bond a year is 0.005
    summ = 0
    y = Symbol('y')
    for i in range(1,maturity-1):
        
        a = (p*(1+coupon)**i-p)/((1+(0.005+y)/2)**(2*i))
        summ = a+summ
    
    summ= summ + p*(1+coupon)**maturity/((1+(0.005+y)/2)**(2*maturity))
    
    
    eqn = Eq(summ, p)
    print(solve(eqn)[1])


zspread(102,5,0.02)


zs = []
for i in range(len(df)):
    p = df.iloc[i,1]
    maturity = int(df.iloc[i,4])
    coupon = df.iloc[i,2]
    zs.append(zspread(p, maturity,coupon))
    
#### didnt finish running coz running time is so long, prolly smt wrong
# Out:
# 0.0385776590249489
# 0.0385776590249489
# 0.0858336789515297
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1493     try:
# -> 1494         rf = evalf_table[type(x)]
#    1495         r = rf(x, prec, options)
#
# KeyError: <class 'sympy.polys.rootoftools.ComplexRootOf'>
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/gz/q5mfwhqd62b5zrb2w6579f140000gn/T/ipykernel_42347/2294812314.py in <module>
#      22     maturity = int(df.iloc[i,4])
#      23     coupon = df.iloc[i,2]
# ---> 24     zs.append(zspread(p, maturity,coupon))
#      25
#      26
#
# /var/folders/gz/q5mfwhqd62b5zrb2w6579f140000gn/T/ipykernel_42347/2294812314.py in zspread(p, maturity, coupon)
#      11
#      12     eqn = Eq(summ, p)
# ---> 13     print(solve(eqn)[1])
#      14
#      15
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1104     ###########################################################################
#    1105     if bare_f:
# -> 1106         solution = _solve(f[0], *symbols, **flags)
#    1107     else:
#    1108         solution = _solve_system(f, symbols, **flags)
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1730         # if in doubt, keep it
#    1731         dens = _simple_dens(f, symbols)
# -> 1732         result = [s for s in result if
#    1733                   not any(checksol(d, {symbol: s}, **flags)
#    1734                           for d in dens)]
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/solvers/solvers.py in <listcomp>(.0)
#    1731         dens = _simple_dens(f, symbols)
#    1732         result = [s for s in result if
# -> 1733                   not any(checksol(d, {symbol: s}, **flags)
#    1734                           for d in dens)]
#    1735     if check:
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/solvers/solvers.py in <genexpr>(.0)
#    1731         dens = _simple_dens(f, symbols)
#    1732         result = [s for s in result if
# -> 1733                   not any(checksol(d, {symbol: s}, **flags)
#    1734                           for d in dens)]
#    1735     if check:
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/solvers/solvers.py in checksol(f, symbol, sol, **flags)
#     365             return val == 0
#     366         if numerical and val.is_number:
# --> 367             return (abs(val.n(18).n(12, chop=True)) < 1e-9) is S.true
#     368         was = val
#     369
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/core/evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1656             options['quad'] = quad
#    1657         try:
# -> 1658             result = evalf(self, prec + 4, options)
#    1659         except NotImplementedError:
#    1660             # Fall back to the ordinary evalf
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1493     try:
#    1494         rf = evalf_table[type(x)]
# -> 1495         r = rf(x, prec, options)
#    1496     except KeyError:
#    1497         # Fall back to ordinary evalf if possible
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/core/evalf.py in evalf_add(v, prec, options)
#     600         options['maxprec'] = min(oldmaxprec, 2*prec)
#     601
# --> 602         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603         n = terms.count(S.ComplexInfinity)
#     604         if n >= 2:
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/core/evalf.py in <listcomp>(.0)
#     600         options['maxprec'] = min(oldmaxprec, 2*prec)
#     601
# --> 602         terms = [evalf(arg, prec + 10, options) for arg in v.args]
#     603         n = terms.count(S.ComplexInfinity)
#     604         if n >= 2:
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1493     try:
#    1494         rf = evalf_table[type(x)]
# -> 1495         r = rf(x, prec, options)
#    1496     except KeyError:
#    1497         # Fall back to ordinary evalf if possible
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/core/evalf.py in evalf_mul(v, prec, options)
#     648     from .numbers import Float
#     649     for arg in args:
# --> 650         result = evalf(arg, prec, options)
#     651         if result is S.ComplexInfinity:
#     652             special.append(result)
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/core/evalf.py in evalf(x, prec, options)
#    1498         if 'subs' in options:
#    1499             x = x.subs(evalf_subs(prec, options['subs']))
# -> 1500         xe = x._eval_evalf(prec)
#    1501         if xe is None:
#    1502             raise NotImplementedError
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/rootoftools.py in _eval_evalf(self, prec, **kwargs)
#     893         """Evaluate this complex root to the given precision."""
#     894         # all kwargs are ignored
# --> 895         return self.eval_rational(n=prec_to_dps(prec))._evalf(prec)
#     896
#     897     def eval_rational(self, dx=None, dy=None, n=15):
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/rootoftools.py in eval_rational(self, dx, dy, n)
#     964                     dx = abs(interval.center[0]*rtol)
#     965                     dy = abs(interval.center[1]*rtol)
# --> 966                 interval = interval.refine_size(dx, dy)
#     967                 c = interval.center
#     968                 real, imag = map(Rational, c)
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/rootisolation.py in refine_size(self, dx, dy)
#    2181         expr = self
#    2182         while not (expr.dx < dx and expr.dy < dy):
# -> 2183             expr = expr._inner_refine()
#    2184
#    2185         return expr
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/rootisolation.py in _inner_refine(self)
#    2158                 _, a, b, I, Q, F1, F2 = D_R
#    2159         else:
# -> 2160             D_B, D_U = _horizontal_bisection(1, (u, v), (s, t), I, Q, F1, F2, f1, f2, dom)
#    2161
#    2162             if D_B[0] == 1:
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/rootisolation.py in _horizontal_bisection(N, a, b, I, Q, F1, F2, f1, f2, F)
#    1470     f2H = dmp_eval_in(f2, y, 1, 1, F)
#    1471
# -> 1472     I_H = dup_isolate_real_roots_list([f1H, f2H], F, inf=u, sup=s, fast=True, strict=True, basis=True)
#    1473
#    1474     I_L1_B, I_L1_U = I_L1, I_H
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/rootisolation.py in dup_isolate_real_roots_list(polys, K, eps, inf, sup, strict, basis, fast)
#     665             zero_indices[i] = j
#     666
# --> 667         for f, k in dup_factor_list(p, K)[1]:
#     668             f = tuple(f)
#     669
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_factor_list(f, K0)
#    1328
#    1329         if K.is_ZZ:
# -> 1330             coeff, factors = dup_zz_factor(f, K)
#    1331         elif K.is_Poly:
#    1332             f, u = dmp_inject(f, 0, K)
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_zz_factor(f, K)
#     674
#     675     if H is None:
# --> 676         H = dup_zz_zassenhaus(g, K)
#     677
#     678     factors = dup_trial_division(f, H, K)
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_zz_zassenhaus(f, K)
#     351     modular = [gf_to_int_poly(ff, p) for ff in fsqf]
#     352
# --> 353     g = dup_zz_hensel_lift(p, f, modular, l, K)
#     354
#     355     sorted_T = range(len(g))
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_zz_hensel_lift(p, f, f_list, l, K)
#     301
#     302     for _ in range(1, d + 1):
# --> 303         (g, h, s, t), m = dup_zz_hensel_step(m, f, g, h, s, t, K), m**2
#     304
#     305     return dup_zz_hensel_lift(p, g, f_list[:k], l, K) \
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/factortools.py in dup_zz_hensel_step(m, f, g, h, s, t, K)
#     237     b = dup_trunc(dup_sub(u, [K.one], K), M, K)
#     238
# --> 239     c, d = dup_div(dup_mul(s, b, K), H, K)
#     240
#     241     c = dup_trunc(c, M, K)
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/densearith.py in dup_div(f, g, K)
#    1534         return dup_ff_div(f, g, K)
#    1535     else:
# -> 1536         return dup_rr_div(f, g, K)
#    1537
#    1538
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/densearith.py in dup_rr_div(f, g, K)
#    1342
#    1343         q = dup_add_term(q, c, j, K)
# -> 1344         h = dup_mul_term(g, c, j, K)
#    1345         r = dup_sub(r, h, K)
#    1346
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/densearith.py in dup_mul_term(f, c, i, K)
#     155         return []
#     156     else:
# --> 157         return [ cf * c for cf in f ] + [K.zero]*i
#     158
#     159
#
# ~/opt/miniconda3/envs/tf/lib/python3.9/site-packages/sympy/polys/densearith.py in <listcomp>(.0)
#     155         return []
#     156     else:
# --> 157         return [ cf * c for cf in f ] + [K.zero]*i
#     158
#     159
#
# KeyboardInterrupt:

# %%
######### part3: implied spread for the whole pool############
## average of zs
# Out:
# [None, None]
